# %% [markdown]
# # 1. Convert JSON to DataFrame

# %%
import pandas as pd
import json
import re
import os
import math

def problem_unification(problem_str):
    ### this function unifies the column 'problem' between GPT-3 and Google's LMs datasets
    # e.g., problem_str = 'mult_data_wrangling:some_before_at_na_emails_1'
    problem = re.findall(r":(.+)_[a-z]+_[\d]+", problem_str)[0]
    problem_parts = problem.split('_')
    problem_str = problem_parts[0]
    
    for i, part in enumerate(problem_parts[1:]):
        i += 1
        if i == len(problem_parts) - 1:
            if part == 'na':
                part = 'NA'
            problem_str = problem_str + '-' + part
        else:
            problem_str = problem_str + part[0].upper() + part[1:] 
            
    return problem_str


def convert_JSONs_to_df(directory):
    path_to_json = directory
    json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
    # print(json_files)
    lis = []
    lis_prob = []
    for json_file in json_files:
        # print(json_file)
        with open(directory + json_file, encoding="utf8") as json_obj:
            data = json.load(json_obj)
            engine = data['model']['model_family'] + ' ' + data['model']['model_name']
            # non_embedding_params = data['model']['non_embedding_params']
            total_params = data['model']['total_params']
            
            
            for query in data['queries']:
                if query['function'] == 'generate_text': 
                    for sample in query['samples']:
                        problem = problem_unification(query['task'] )
                        domain = re.findall(r"_([a-z]+)_[\d]+$", query['task'])[0]
                        nshot = query['shots']
                        q = sample['input']   # query's input 
                        target = [t for t in sample['targets'].keys()][0]
                        output = sample['output']

 
                        correct = 1 if int([t for t in sample['targets'].values()][0]['exact_str_match']) == 1 else 0

                        lis.append([problem, domain, engine, nshot, q, target, 
                                    output, correct, total_params])
                else:
                    for sample in query["samples"]:
                        lis_prob.append(math.exp(sample["absolute_scores"][0]))
    df = pd.DataFrame(lis)
    df.columns = ['problem', 'domain', 'engine', 'nshot', 'query', 
                   'target', 'output', 'correct', 'total_params']
    df['prob'] = lis_prob
    return df
    
df = convert_JSONs_to_df('./datasets/full-logs_BIG-G_BIG-G-sparse_JSON_230422/')

# %%
"""
I have to:
1. extract the domain --> Done!
2. unify the column 'problem' for both datasets  --> Done!
3. run all the files for different LMs of Google  --> Done!
4. extract non_embedding_params and total_params for GPT3 dataset (of Nando) --> Done!
5. Then, try to think about what to do with the 'query' column


Notes:

Google's LMs only have up to 3shots 
Can different shots have different meta-features?
Then, maybe we should provide more meta-features (a set for each shot)
"""


df
# Out:
#                  problem    domain             engine  nshot  \
# 0       addPunctuation-1     dates  BIG-G sparse 125m      0
# 1       addPunctuation-1     dates  BIG-G sparse 125m      0
# 2       addPunctuation-1     dates  BIG-G sparse 125m      0
# 3       addPunctuation-1     dates  BIG-G sparse 125m      0
# 4       addPunctuation-1     dates  BIG-G sparse 125m      1
# ...                  ...       ...                ...    ...
# 133819         toUpper-2  freetext       BIG-G T=1 8b      2
# 133820         toUpper-2  freetext       BIG-G T=1 8b      3
# 133821         toUpper-2  freetext       BIG-G T=1 8b      3
# 133822         toUpper-2  freetext       BIG-G T=1 8b      3
# 133823         toUpper-2  freetext       BIG-G T=1 8b      3
#
#                                                     query  \
# 0                                Input: '110892' Output:
# 1                                Input: '021097' Output:
# 2                                Input: '270906' Output:
# 3                                Input: '030796' Output:
# 4       Input: '290386' Output: '29-03-86'\n\nInput: '...
# ...                                                   ...
# 133819  the input string/s 'Aquila non capit muscas.' ...
# 133820  the input string/s 'Lorem ipsum dolor sit amet...
# 133821  the input string/s 'Integer malesuada elit et ...
# 133822  the input string/s 'Quid infantes sumus.' is/a...
# 133823  the input string/s 'Aquila non capit muscas.' ...
#
#                                                 target  \
# 0                                           '11-08-92'
# 1                                           '02-10-97'
# 2                                           '27-09-06'
# 3                                           '03-07-96'
# 4                                           '11-08-92'
# ...                                                ...
# 133819            'NEMO MORTALIUM OMNIBUS HORIS SAPIT'
# 133820                                'TIBI BENE VOLO'
# 133821  'FERE LIBENTER HOMINES ID QUOD VOLUNT CREDUNT'
# 133822                       'PLACE DICES MIHI LATINE'
# 133823            'NEMO MORTALIUM OMNIBUS HORIS SAPIT'
#
#                                                output  correct  total_params  \
# 0                                            '110892'        0    1777677312
# 1                                            '021097'        0    1777677312
# 2                                            '270906'        0    1777677312
# 3                                            '030796'        0    1777677312
# 4                                            '110892'        0    1777677312
# ...                                               ...      ...           ...
# 133819             'NEMO MORTIS OMNIBUS HORIS SAPIT.'        0    8721174528
# 133820                               'TIBI BENE VOLO'        1    8721174528
# 133821  'FERE LIBENTER HOMINIS ID QUOD VOLUNT CREDIT'        0    8721174528
# 133822                       'Place dices mihi LATIN'        0    8721174528
# 133823          'NEMO MORTIALUM OMNUM HORIS SAPITER.'        0    8721174528
#
#                 prob
# 0       4.325552e-09
# 1       9.040107e-05
# 2       8.287534e-10
# 3       1.314212e-04
# 4       1.050140e-04
# ...              ...
# 133819  1.032499e-01
# 133820  5.012325e-01
# 133821  1.070722e-03
# 133822  5.949777e-02
# 133823  9.019163e-02
#
# [133824 rows x 10 columns]

# %%
df.to_csv('./datasets/Google.DataWrangling.csv')

# %% [markdown]
# # 2. Convert query columns into "input_{i}" and "output_{i}" columns

# %% [markdown]
# ## 2.1. Google's LMs

# %%
import re
import numpy as np

N = len(df['query'])
Inputs = [[np.NaN] * N for i in range(11)]
Outputs = [[np.NaN] * N for i in range(10)]
PromptFormat = [np.NaN] * N

ok = []
for i in range(N):
    row = df['query'][i]
    
    if row[:6] == 'Input:':
        PromptFormat[i] = 2
        res = [val for val in re.split(r'\n\n', df['query'][i])]
        for j, lis in enumerate(res):
            
            if j == df['nshot'][i]:   # The test input
                Inputs[-1][i] = re.findall(r"Input: '(.+)' Output: ", lis)[0].replace("', '", ", ")
            
            else:  # one of the nshot input
                Inputs[j][i] = re.findall(r"Input: '(.+)' Output", lis)[0].replace("', '", ", ")
                
                if len(re.findall(r"Output: '(.+)'", lis)) != 0:
                    Outputs[j][i] = re.findall(r"Output: '(.+)'", lis)[0].replace("', '", ", ")
                    
    else:     # row[:3] == 'the':
        PromptFormat[i] = 3
        res = re.split(';', row)
        for j, lis in enumerate(res):
            
            if j == df['nshot'][i]:
                Inputs[-1][i] = re.findall(r"the input string/s '(.+)' is/are formatted as ", lis)[0].replace("', '", ", ")
            
            else:
                Inputs[j][i] = re.findall(r"the input string/s '(.+)' is/are formatted as ", lis)[0].replace("', '", ", ")
                
                if len(re.findall(r"is/are formatted as '(.+)'", lis)) != 0:
                    Outputs[j][i] = re.findall(r"is/are formatted as '(.+)'", lis)[0].replace("', '", ", ")

print(Inputs)
print(Outputs)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
PromptFormat_df = pd.DataFrame(PromptFormat)
PromptFormat_df.columns = ["prompt_format"]

input_df = pd.DataFrame(Inputs).transpose()
input_df.columns = ["input"+str(i) for i in range(1,12)]
input_df

output_df = pd.DataFrame(Outputs).transpose()
output_df.columns = ["output"+str(i) for i in range(1,11)]
output_df

int_out_df_GG_aux = pd.concat([PromptFormat_df.reset_index(drop=True), input_df], axis = 1)
int_out_df_GG = pd.concat([int_out_df_GG_aux.reset_index(drop=True), output_df], axis = 1) 
int_out_df_GG
# Out:
#         prompt_format                                             input1  \
# 0                   2                                                NaN
# 1                   2                                                NaN
# 2                   2                                                NaN
# 3                   2                                                NaN
# 4                   2                                             290386
# ...               ...                                                ...
# 133819              3                           Aquila non capit muscas.
# 133820              3  Lorem ipsum dolor sit amet, consectetur adipis...
# 133821              3     Integer malesuada elit et hendrerit fermentum.
# 133822              3                               Quid infantes sumus.
# 133823              3                           Aquila non capit muscas.
#
#                                                    input2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 133819                           Haec domina toto pendet.
# 133820    Pellentesque tempor justo a dui varius maximus.
# 133821                              Denuntiatores vocate.
# 133822  Praesent sed ipsum euismod, tempor dolor at. v...
# 133823                           Haec domina toto pendet.
#
#                                                    input3 input4 input5  \
# 0                                                     NaN    NaN    NaN
# 1                                                     NaN    NaN    NaN
# 2                                                     NaN    NaN    NaN
# 3                                                     NaN    NaN    NaN
# 4                                                     NaN    NaN    NaN
# ...                                                   ...    ...    ...
# 133819                                                NaN    NaN    NaN
# 133820                                       Bona Noctem.    NaN    NaN
# 133821                           Aquila non capit muscas.    NaN    NaN
# 133822    Pellentesque tempor justo a dui varius maximus.    NaN    NaN
# 133823  Praesent sed ipsum euismod, tempor dolor at. v...    NaN    NaN
#
#        input6 input7 input8 input9  ...  \
# 0         NaN    NaN    NaN    NaN  ...
# 1         NaN    NaN    NaN    NaN  ...
# 2         NaN    NaN    NaN    NaN  ...
# 3         NaN    NaN    NaN    NaN  ...
# 4         NaN    NaN    NaN    NaN  ...
# ...       ...    ...    ...    ...  ...
# 133819    NaN    NaN    NaN    NaN  ...
# 133820    NaN    NaN    NaN    NaN  ...
# 133821    NaN    NaN    NaN    NaN  ...
# 133822    NaN    NaN    NaN    NaN  ...
# 133823    NaN    NaN    NaN    NaN  ...
#
#                                                   output1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                29-03-86
# ...                                                   ...
# 133819                            AQUILA NON CAPIT MUSCAS
# 133820  LOREM IPSUM DOLOR SIT AMET. CONSECTETUR ADIPIS...
# 133821      INTEGER MALESUADA ELIT ET HENDRERIT FERMENTUM
# 133822                                QUID INFANTES SUMUS
# 133823                            AQUILA NON CAPIT MUSCAS
#
#                                                   output2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 133819                            HAEC DOMINA TOTO PENDET
# 133820     PELLENTESQUE TEMPOR JUSTO A DUI VARIUS MAXIMUS
# 133821                               DENUNTIATORES VOCATE
# 133822  PRAESENT SED IPSUM EUISMOD. TEMPOR DOLOR AT. V...
# 133823                            HAEC DOMINA TOTO PENDET
#
#                                                   output3 output4 output5  \
# 0                                                     NaN     NaN     NaN
# 1                                                     NaN     NaN     NaN
# 2                                                     NaN     NaN     NaN
# 3                                                     NaN     NaN     NaN
# 4                                                     NaN     NaN     NaN
# ...                                                   ...     ...     ...
# 133819                                                NaN     NaN     NaN
# 133820                                        BONA NOCTEM     NaN     NaN
# 133821                            AQUILA NON CAPIT MUSCAS     NaN     NaN
# 133822     PELLENTESQUE TEMPOR JUSTO A DUI VARIUS MAXIMUS     NaN     NaN
# 133823  PRAESENT SED IPSUM EUISMOD. TEMPOR DOLOR AT. V...     NaN     NaN
#
#        output6 output7 output8 output9 output10
# 0          NaN     NaN     NaN     NaN      NaN
# 1          NaN     NaN     NaN     NaN      NaN
# 2          NaN     NaN     NaN     NaN      NaN
# 3          NaN     NaN     NaN     NaN      NaN
# 4          NaN     NaN     NaN     NaN      NaN
# ...        ...     ...     ...     ...      ...
# 133819     NaN     NaN     NaN     NaN      NaN
# 133820     NaN     NaN     NaN     NaN      NaN
# 133821     NaN     NaN     NaN     NaN      NaN
# 133822     NaN     NaN     NaN     NaN      NaN
# 133823     NaN     NaN     NaN     NaN      NaN
#
# [133824 rows x 22 columns]

# %% [markdown]
# ## 2.2. GPT-3

# %%
df = pd.read_csv("./datasets/GPT3.DataWrangling.csv")
df
# Out:
#         Unnamed: 0           problem domain   engine  nshot  \
# 0                1  addPunctuation-1  dates  davinci      0
# 1                2  addPunctuation-1  dates  davinci      0
# 2                3  addPunctuation-1  dates  davinci      0
# 3                4  addPunctuation-1  dates  davinci      0
# 4                5  addPunctuation-1  dates  davinci      0
# ...            ...               ...    ...      ...    ...
# 146119      146120        getValue-2  units      ada     10
# 146120      146121        getValue-2  units      ada     10
# 146121      146122        getValue-2  units      ada     10
# 146122      146123        getValue-2  units      ada     10
# 146123      146124        getValue-2  units      ada     10
#
#                                                     query    target  output  \
# 0                                  Input: 290386\nOutput:  29-03-86  290104
# 1                                  Input: 250374\nOutput:  25-03-74  250375
# 2                                  Input: 170615\nOutput:  17-06-15  170616
# 3                                  Input: 170905\nOutput:  17-09-05  170905
# 4                                  Input: 241206\nOutput:  24-12-06  241206
# ...                                                   ...       ...     ...
# 146119  Input: 7cm\nOutput: 7\n\nInput: 67mm\nOutput: ...        78      78
# 146120  Input: 7cm\nOutput: 7\n\nInput: 67mm\nOutput: ...     56676  56776g
# 146121  Input: 7cm\nOutput: 7\n\nInput: 67mm\nOutput: ...        56      56
# 146122  Input: 7cm\nOutput: 7\n\nInput: 67mm\nOutput: ...         7       7
# 146123  Input: 7cm\nOutput: 7\n\nInput: 67mm\nOutput: ...        56      56
#
#         correct  total_params      prob
# 0             0  1.750000e+11  0.000888
# 1             0  1.750000e+11  0.079038
# 2             0  1.750000e+11  0.232628
# 3             0  1.750000e+11  0.239137
# 4             0  1.750000e+11  0.075100
# ...         ...           ...       ...
# 146119        1  3.500000e+08  0.900076
# 146120        0  3.500000e+08  0.821654
# 146121        1  3.500000e+08  0.972055
# 146122        1  3.500000e+08  0.970601
# 146123        1  3.500000e+08  0.967245
#
# [146124 rows x 11 columns]

# %%
import re
import numpy as np

N = len(df['query'])
Inputs = [[np.NaN] * N for i in range(11)]
Outputs = [[np.NaN] * N for i in range(10)]

for i in range(N):
    res = [re.split(r"\\n", val) for val in re.split(r'\\n\\n', df['query'][i])]
    for j, lis in enumerate(res):
        if j == df['nshot'][i]:
            Inputs[-1][i] = re.findall(r"Input: (.+)", lis[0])[0]
            
        else:
            Inputs[j][i] = re.findall(r"Input: (.+)", lis[0])[0]
            if len(re.findall(r"Output: (.+)", lis[1])) != 0:
                Outputs[j][i] = re.findall(r"Output: (.+)", lis[1])[0] 

print(Inputs)
print(Outputs)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
PromptFormat_df = pd.DataFrame([1 for i in range(len(df['query']))])
PromptFormat_df.columns = ["prompt_format"]

input_df = pd.DataFrame(Inputs).transpose()
input_df.columns = ["input"+str(i) for i in range(1,12)]
input_df

output_df = pd.DataFrame(Outputs).transpose()
output_df.columns = ["output"+str(i) for i in range(1,11)]
output_df

int_out_df_GPT3_aux = pd.concat([PromptFormat_df.reset_index(drop=True), input_df], axis = 1)  # concat by columns
int_out_df_GPT3 = pd.concat([int_out_df_GPT3_aux.reset_index(drop=True), output_df], axis = 1)  # concat by columns
int_out_df_GPT3
# Out:
#         prompt_format input1 input2      input3 input4 input5     input6  \
# 0                   1    NaN    NaN         NaN    NaN    NaN        NaN
# 1                   1    NaN    NaN         NaN    NaN    NaN        NaN
# 2                   1    NaN    NaN         NaN    NaN    NaN        NaN
# 3                   1    NaN    NaN         NaN    NaN    NaN        NaN
# 4                   1    NaN    NaN         NaN    NaN    NaN        NaN
# ...               ...    ...    ...         ...    ...    ...        ...
# 146119              1    7cm   67mm  7890.12 km  345 K  21 cm  4235.11 m
# 146120              1    7cm   67mm  7890.12 km  345 K  21 cm  4235.11 m
# 146121              1    7cm   67mm  7890.12 km  345 K  21 cm  4235.11 m
# 146122              1    7cm   67mm  7890.12 km  345 K  21 cm  4235.11 m
# 146123              1    7cm   67mm  7890.12 km  345 K  21 cm  4235.11 m
#
#         input7  input8 input9  ... output1 output2  output3 output4 output5  \
# 0          NaN     NaN    NaN  ...     NaN     NaN      NaN     NaN     NaN
# 1          NaN     NaN    NaN  ...     NaN     NaN      NaN     NaN     NaN
# 2          NaN     NaN    NaN  ...     NaN     NaN      NaN     NaN     NaN
# 3          NaN     NaN    NaN  ...     NaN     NaN      NaN     NaN     NaN
# 4          NaN     NaN    NaN  ...     NaN     NaN      NaN     NaN     NaN
# ...        ...     ...    ...  ...     ...     ...      ...     ...     ...
# 146119  90 mol  423 ml   34mm  ...       7      67  7890.12     345      21
# 146120  90 mol  423 ml   34mm  ...       7      67  7890.12     345      21
# 146121  90 mol  423 ml   34mm  ...       7      67  7890.12     345      21
# 146122  90 mol  423 ml   34mm  ...       7      67  7890.12     345      21
# 146123  90 mol  423 ml   34mm  ...       7      67  7890.12     345      21
#
#         output6 output7 output8 output9 output10
# 0           NaN     NaN     NaN     NaN      NaN
# 1           NaN     NaN     NaN     NaN      NaN
# 2           NaN     NaN     NaN     NaN      NaN
# 3           NaN     NaN     NaN     NaN      NaN
# 4           NaN     NaN     NaN     NaN      NaN
# ...         ...     ...     ...     ...      ...
# 146119  4235.11      90     423      34       56
# 146120  4235.11      90     423      34       56
# 146121  4235.11      90     423      34       56
# 146122  4235.11      90     423      34       56
# 146123  4235.11      90     423      34       56
#
# [146124 rows x 22 columns]

# %% [markdown]
# # 3. Final integration

# %%
df_GPT3 = pd.read_csv("./datasets/GPT3.DataWrangling.csv")
df_Google = pd.read_csv("./datasets/Google.DataWrangling.csv")
df_both_aux = pd.concat([df_GPT3.reset_index(drop=True), df_Google], axis = 0)
df_both = df_both_aux.drop('Unnamed: 0', inplace=False, axis=1)
df_both.reset_index(inplace=True)

# %%
int_out_df_both = pd.concat([int_out_df_GPT3.reset_index(drop=True), int_out_df_GG], axis = 0)
int_out_df_both.reset_index(inplace=True)

# %%
df_cleaned = pd.concat([df_both.reset_index(drop=True), int_out_df_both], axis = 1)
df_cleaned.drop('index', inplace=True, axis=1)
df_cleaned.rename(columns = {'input11':'test_input'}, inplace = True)
df_cleaned
# Out:
#                  problem    domain        engine  nshot  \
# 0       addPunctuation-1     dates       davinci      0
# 1       addPunctuation-1     dates       davinci      0
# 2       addPunctuation-1     dates       davinci      0
# 3       addPunctuation-1     dates       davinci      0
# 4       addPunctuation-1     dates       davinci      0
# ...                  ...       ...           ...    ...
# 279943         toUpper-2  freetext  BIG-G T=1 8b      2
# 279944         toUpper-2  freetext  BIG-G T=1 8b      3
# 279945         toUpper-2  freetext  BIG-G T=1 8b      3
# 279946         toUpper-2  freetext  BIG-G T=1 8b      3
# 279947         toUpper-2  freetext  BIG-G T=1 8b      3
#
#                                                     query  \
# 0                                  Input: 290386\nOutput:
# 1                                  Input: 250374\nOutput:
# 2                                  Input: 170615\nOutput:
# 3                                  Input: 170905\nOutput:
# 4                                  Input: 241206\nOutput:
# ...                                                   ...
# 279943  the input string/s 'Aquila non capit muscas.' ...
# 279944  the input string/s 'Lorem ipsum dolor sit amet...
# 279945  the input string/s 'Integer malesuada elit et ...
# 279946  the input string/s 'Quid infantes sumus.' is/a...
# 279947  the input string/s 'Aquila non capit muscas.' ...
#
#                                                 target  \
# 0                                             29-03-86
# 1                                             25-03-74
# 2                                             17-06-15
# 3                                             17-09-05
# 4                                             24-12-06
# ...                                                ...
# 279943            'NEMO MORTALIUM OMNIBUS HORIS SAPIT'
# 279944                                'TIBI BENE VOLO'
# 279945  'FERE LIBENTER HOMINES ID QUOD VOLUNT CREDUNT'
# 279946                       'PLACE DICES MIHI LATINE'
# 279947            'NEMO MORTALIUM OMNIBUS HORIS SAPIT'
#
#                                                output  correct  total_params  \
# 0                                              290104        0  1.750000e+11
# 1                                              250375        0  1.750000e+11
# 2                                              170616        0  1.750000e+11
# 3                                              170905        0  1.750000e+11
# 4                                              241206        0  1.750000e+11
# ...                                               ...      ...           ...
# 279943             'NEMO MORTIS OMNIBUS HORIS SAPIT.'        0  8.721175e+09
# 279944                               'TIBI BENE VOLO'        1  8.721175e+09
# 279945  'FERE LIBENTER HOMINIS ID QUOD VOLUNT CREDIT'        0  8.721175e+09
# 279946                       'Place dices mihi LATIN'        0  8.721175e+09
# 279947          'NEMO MORTIALUM OMNUM HORIS SAPITER.'        0  8.721175e+09
#
#             prob  ...                                            output1  \
# 0       0.000888  ...                                                NaN
# 1       0.079038  ...                                                NaN
# 2       0.232628  ...                                                NaN
# 3       0.239137  ...                                                NaN
# 4       0.075100  ...                                                NaN
# ...          ...  ...                                                ...
# 279943  0.103250  ...                            AQUILA NON CAPIT MUSCAS
# 279944  0.501232  ...  LOREM IPSUM DOLOR SIT AMET. CONSECTETUR ADIPIS...
# 279945  0.001071  ...      INTEGER MALESUADA ELIT ET HENDRERIT FERMENTUM
# 279946  0.059498  ...                                QUID INFANTES SUMUS
# 279947  0.090192  ...                            AQUILA NON CAPIT MUSCAS
#
#                                                   output2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 279943                            HAEC DOMINA TOTO PENDET
# 279944     PELLENTESQUE TEMPOR JUSTO A DUI VARIUS MAXIMUS
# 279945                               DENUNTIATORES VOCATE
# 279946  PRAESENT SED IPSUM EUISMOD. TEMPOR DOLOR AT. V...
# 279947                            HAEC DOMINA TOTO PENDET
#
#                                                   output3 output4 output5  \
# 0                                                     NaN     NaN     NaN
# 1                                                     NaN     NaN     NaN
# 2                                                     NaN     NaN     NaN
# 3                                                     NaN     NaN     NaN
# 4                                                     NaN     NaN     NaN
# ...                                                   ...     ...     ...
# 279943                                                NaN     NaN     NaN
# 279944                                        BONA NOCTEM     NaN     NaN
# 279945                            AQUILA NON CAPIT MUSCAS     NaN     NaN
# 279946     PELLENTESQUE TEMPOR JUSTO A DUI VARIUS MAXIMUS     NaN     NaN
# 279947  PRAESENT SED IPSUM EUISMOD. TEMPOR DOLOR AT. V...     NaN     NaN
#
#        output6 output7 output8 output9 output10
# 0          NaN     NaN     NaN     NaN      NaN
# 1          NaN     NaN     NaN     NaN      NaN
# 2          NaN     NaN     NaN     NaN      NaN
# 3          NaN     NaN     NaN     NaN      NaN
# 4          NaN     NaN     NaN     NaN      NaN
# ...        ...     ...     ...     ...      ...
# 279943     NaN     NaN     NaN     NaN      NaN
# 279944     NaN     NaN     NaN     NaN      NaN
# 279945     NaN     NaN     NaN     NaN      NaN
# 279946     NaN     NaN     NaN     NaN      NaN
# 279947     NaN     NaN     NaN     NaN      NaN
#
# [279948 rows x 32 columns]

# %%
df_cleaned.columns
# Out:
# Index(['problem', 'domain', 'engine', 'nshot', 'query', 'target', 'output',
#        'correct', 'total_params', 'prob', 'prompt_format', 'input1', 'input2',
#        'input3', 'input4', 'input5', 'input6', 'input7', 'input8', 'input9',
#        'input10', 'test_input', 'output1', 'output2', 'output3', 'output4',
#        'output5', 'output6', 'output7', 'output8', 'output9', 'output10'],
#       dtype='object')

# %% [markdown]
# ## 3.1. Derivating some syst_features

# %%
temperature = []
sparsity = []
model_family = []

for engine in df_cleaned.engine:
    ### Temperature (note: GPT-3 engines used T=0)
    temperature.append(1) if "T=1" in engine else temperature.append(0)
    ### sparsity
    sparsity.append(1) if "sparse" in engine else sparsity.append(0)
    ### model_family
    if "sparse" in engine:
        model_family.append("BIG-G sparse")
    elif "T=0" in engine:
        model_family.append("BIG-G T=0")
    elif "T=1" in engine:
        model_family.append("BIG-G T=1")
    else:
        model_family.append("GPT-3")

# %%
import collections
print(collections.Counter(temperature))
print(collections.Counter(sparsity))
print(collections.Counter(model_family))
# Out:
# Counter({0: 232716, 1: 47232})
# Counter({0: 240588, 1: 39360})
# Counter({'GPT-3': 146124, 'BIG-G T=0': 47232, 'BIG-G T=1': 47232, 'BIG-G sparse': 39360})

# %%
df_cleaned.insert(10, column="temperature", value=temperature)
df_cleaned.insert(11, column="sparsity", value=sparsity)
df_cleaned.insert(12, column="model_family", value=model_family)

# %%
df_cleaned.columns
# Out:
# Index(['problem', 'domain', 'engine', 'nshot', 'query', 'target', 'output',
#        'correct', 'total_params', 'prob', 'temperature', 'sparsity',
#        'model_family', 'prompt_format', 'input1', 'input2', 'input3', 'input4',
#        'input5', 'input6', 'input7', 'input8', 'input9', 'input10',
#        'test_input', 'output1', 'output2', 'output3', 'output4', 'output5',
#        'output6', 'output7', 'output8', 'output9', 'output10'],
#       dtype='object')

# %%
df_cleaned.to_csv('./datasets/GPT3.and.Google.DataWrangling.csv')
